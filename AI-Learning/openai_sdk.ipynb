# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # 从 .env 文件加载环境变量
api_key = os.environ.get("DEEPSEEK_API_KEY")
# print(api_key)
# Out:
# True
# sk-007dabbea0624bf3ba65da1a6694f514

# %%
# Please install OpenAI SDK first: `pip3 install openai`
import os
from openai import OpenAI

client = OpenAI(
    api_key=os.environ.get('DEEPSEEK_API_KEY'),
    base_url="https://api.deepseek.com")

response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Hello"},
    ],
    stream=False
)

print(response.choices[0].message.content)
# Out:
# Hello! How can I assist you today? 😊

# %% [markdown]
# https://docs.apiyi.com/wiki/tools/openai-sdk

# %%
import openai
from openai import OpenAI
import asyncio
from typing import List, Dict, Any
import os
from dotenv import load_dotenv

# 加载环境变量
load_dotenv()

class DeepSeekClient:
    def __init__(self, api_key: str = None):
        # 如果没有提供 api_key，从环境变量中获取
        if api_key is None:
            api_key = os.environ.get('DEEPSEEK_API_KEY')
    
        self.client = OpenAI(
            api_key=api_key,
            base_url="https://api.deepseek.com"
        )
        self.async_client = openai.AsyncOpenAI(
            api_key=api_key,
            base_url="https://api.deepseek.com"
        )

    def chat_completion(self, messages: List[Dict], model: str = "deepseek-chat"):
        """同步聊天完成"""
        try:
            response = self.client.chat.completions.create(
                model=model,
                messages=messages,
                temperature=0.7,
                max_tokens=2000,
                top_p=1.0,
                frequency_penalty=0.0,
                presence_penalty=0.0
            )
            
            return {
                "content": response.choices[0].message.content,
                "usage": {
                    "prompt_tokens": response.usage.prompt_tokens,
                    "completion_tokens": response.usage.completion_tokens,
                    "total_tokens": response.usage.total_tokens
                },
                "model": response.model,
                "finish_reason": response.choices[0].finish_reason
            }
        
        except openai.RateLimitError as e:
            return {"error": "rate_limit", "message": str(e)}
        except openai.AuthenticationError as e:
            return {"error": "auth", "message": str(e)}
        except Exception as e:
            return {"error": "general", "message": str(e)}
    
    async def async_chat_completion(self, messages: List[Dict], model: str = "deepseek-chat"):
        """异步聊天完成"""
        try:
            response = await self.async_client.chat.completions.create(
                model=model,
                messages=messages,
                temperature=0.7,
                max_tokens=2000
            )
            
            return {
                "content": response.choices[0].message.content,
                "usage": dict(response.usage),
                "model": response.model
            }
        
        except Exception as e:
            return {"error": str(e)}

# 使用示例
client = DeepSeekClient(api_key=os.environ.get("DEEPSEEK_API_KEY"))

# 同步调用
response = client.chat_completion([
    {"role": "system", "content": "你是一个有用的AI助手。"},
    {"role": "user", "content": "解释什么是机器学习"}
])

print("同步调用结果:")
print(response)

# 异步调用
async def main():
    response = await client.async_chat_completion([
        {"role": "user", "content": "介绍Python的优势"}
    ])
    return response

# asyncio.run(main())
# Out:
# True
# 同步调用结果:
# {'content': '好的，这是一个关于“机器学习”的全面且易于理解的解释。\n\n### 一句话概括\n\n**机器学习是让计算机通过数据自主学习并改进性能，而无需显式编程的一门人工智能科学。**\n\n换句话说，传统的编程是我们告诉计算机每一步该做什么（输入规则 + 数据 → 输出答案）。而机器学习是我们给计算机输入大量的数据和想要的答案，让它自己找出其中的规律和规则（输入数据 + 答案 → 输出规则）。\n\n---\n\n### 一个生动的比喻：教孩子识别猫\n\n想象一下你要教一个从未见过猫的孩子什么是“猫”。\n\n1.  **传统编程方法**：你需要制定一套精确的规则，例如：“它有尖耳朵、有胡须、四条腿、会喵喵叫、尾巴长……” 但你会发现，有些猫耳朵是折着的，有些没有尾巴，有些狗也符合其中几条规则。这个方法非常僵化且容易出错。\n\n2.  **机器学习方法**：你给孩子看成千上万张不同品种、不同姿态、不同颜色的猫的图片，并告诉他“这些都是猫”。同时，也给他看一些狗、兔子、汽车的图片，并说“这些不是猫”。通过这个过程，孩子的大脑会自发地学习，抽象出“猫”的本质特征（比如脸型、毛发的质感、眼睛的形状等），最终他就能准确地识别出他从未见过的猫。\n\n**机器学习的过程就类似于这个“教孩子”的过程。**\n\n---\n\n### 机器学习的核心三要素\n\n任何一个机器学习系统都包含三个基本组成部分：\n\n1.  **模型（Model）**：就像一个“数学公式”或“大脑结构”。它最初是一张白纸，等待从数据中学习规律。\n2.  **数据（Data）**：就是上面提到的“猫和不是猫的图片”。数据是模型学习的“燃料”和“教材”。数据的数量和质量至关重要。\n3.  **算法（Algorithm）**：就是“学习方法”。它告诉模型如何从数据中调整自己的内部参数，以减小预测的错误。常见的算法有决策树、神经网络、支持向量机等。\n\n---\n\n### 机器学习的主要类型\n\n根据学习方式的不同，机器学习主要分为以下几类：\n\n1.  **监督学习**\n    *   **核心思想**：给模型提供 **“带标签的数据”** 进行训练。就像有答案的学习资料。\n    *   **数据形式**：输入数据 + 对应的正确答案（标签）。\n    *   **目标**：学习输入到输出之间的映射关系，以便对新的、未见过的数据做出准确预测。\n    *   **例子**：\n        *   **分类**：判断邮件是“垃圾邮件”还是“正常邮件”；识别图片中是“猫”还是“狗”。\n        *   **回归**：根据房屋面积、地段预测房价；根据历史数据预测明天的气温。\n\n2.  **无监督学习**\n    *   **核心思想**：给模型提供 **“无标签的数据”** 。就像给了一堆没有分类的杂物，让机器自己发现其中的结构。\n    *   **数据形式**：只有输入数据，没有正确答案。\n    *   **目标**：发现数据中内在的、潜在的模式或分组。\n    *   **例子**：\n        *   **聚类**：根据用户的购买行为将客户分成不同的群组，用于精准营销。\n        *   **降维**：将高维数据（如几百万像素的图片）压缩到低维空间，便于可视化或处理。\n\n3.  **强化学习**\n    *   **核心思想**：像一个“试错学习”的过程。模型（称为智能体）通过与环境的交互，根据获得的“奖励”或“惩罚”来调整自己的行为策略。\n    *   **数据形式**：行动 + 环境反馈（奖励/惩罚）。\n    *   **目标**：学习出一套能获得最大累积奖励的最优策略。\n    *   **例子**：\n        *   **AlphaGo** 通过与自己下棋，赢了得正奖励，输了得负奖励，从而学习出高超的棋艺。\n        *   **自动驾驶汽车**，安全行驶获得正奖励，发生碰撞获得负奖励。\n\n---\n\n### 机器学习的常见应用\n\n机器学习已经渗透到我们生活的方方面面：\n\n*   **推荐系统**： Netflix、淘宝、抖音的个性化推荐。\n*   **图像识别**： 人脸解锁、医疗影像（识别肿瘤）、自动驾驶（识别行人和车辆）。\n*   **自然语言处理**： 智能客服、语音助手（Siri、小爱同学）、机器翻译。\n*   **金融风控**： 信用卡欺诈检测、贷款信用评估。\n*   **搜索引擎**： Google、百度的搜索结果排序。\n\n### 总结\n\n**机器学习本质上是一种从经验中学习的能力。** 它让计算机不再仅仅是执行命令的工具，而是成为了能够从海量数据中发现规律、做出预测和决策的“智能体”。它是当今人工智能浪潮的核心驱动力，正在深刻地改变着世界。\n\n希望这个解释能帮助你理解什么是机器学习！', 'usage': {'prompt_tokens': 13, 'completion_tokens': 1033, 'total_tokens': 1046}, 'model': 'deepseek-chat', 'finish_reason': 'stop'}

# %%
response
# Out:
# {'content': '好的，这是一个关于“机器学习”的全面且易于理解的解释。\n\n### 一句话概括\n\n**机器学习是让计算机通过数据自主学习并改进性能，而无需显式编程的一门人工智能科学。**\n\n换句话说，传统的编程是我们告诉计算机每一步该做什么（输入规则 + 数据 → 输出答案）。而机器学习是我们给计算机输入大量的数据和想要的答案，让它自己找出其中的规律和规则（输入数据 + 答案 → 输出规则）。\n\n---\n\n### 一个生动的比喻：教孩子识别猫\n\n想象一下你要教一个从未见过猫的孩子什么是“猫”。\n\n1.  **传统编程方法**：你需要制定一套精确的规则，例如：“它有尖耳朵、有胡须、四条腿、会喵喵叫、尾巴长……” 但你会发现，有些猫耳朵是折着的，有些没有尾巴，有些狗也符合其中几条规则。这个方法非常僵化且容易出错。\n\n2.  **机器学习方法**：你给孩子看成千上万张不同品种、不同姿态、不同颜色的猫的图片，并告诉他“这些都是猫”。同时，也给他看一些狗、兔子、汽车的图片，并说“这些不是猫”。通过这个过程，孩子的大脑会自发地学习，抽象出“猫”的本质特征（比如脸型、毛发的质感、眼睛的形状等），最终他就能准确地识别出他从未见过的猫。\n\n**机器学习的过程就类似于这个“教孩子”的过程。**\n\n---\n\n### 机器学习的核心三要素\n\n任何一个机器学习系统都包含三个基本组成部分：\n\n1.  **模型（Model）**：就像一个“数学公式”或“大脑结构”。它最初是一张白纸，等待从数据中学习规律。\n2.  **数据（Data）**：就是上面提到的“猫和不是猫的图片”。数据是模型学习的“燃料”和“教材”。数据的数量和质量至关重要。\n3.  **算法（Algorithm）**：就是“学习方法”。它告诉模型如何从数据中调整自己的内部参数，以减小预测的错误。常见的算法有决策树、神经网络、支持向量机等。\n\n---\n\n### 机器学习的主要类型\n\n根据学习方式的不同，机器学习主要分为以下几类：\n\n1.  **监督学习**\n    *   **核心思想**：给模型提供 **“带标签的数据”** 进行训练。就像有答案的学习资料。\n    *   **数据形式**：输入数据 + 对应的正确答案（标签）。\n    *   **目标**：学习输入到输出之间的映射关系，以便对新的、未见过的数据做出准确预测。\n    *   **例子**：\n        *   **分类**：判断邮件是“垃圾邮件”还是“正常邮件”；识别图片中是“猫”还是“狗”。\n        *   **回归**：根据房屋面积、地段预测房价；根据历史数据预测明天的气温。\n\n2.  **无监督学习**\n    *   **核心思想**：给模型提供 **“无标签的数据”** 。就像给了一堆没有分类的杂物，让机器自己发现其中的结构。\n    *   **数据形式**：只有输入数据，没有正确答案。\n    *   **目标**：发现数据中内在的、潜在的模式或分组。\n    *   **例子**：\n        *   **聚类**：根据用户的购买行为将客户分成不同的群组，用于精准营销。\n        *   **降维**：将高维数据（如几百万像素的图片）压缩到低维空间，便于可视化或处理。\n\n3.  **强化学习**\n    *   **核心思想**：像一个“试错学习”的过程。模型（称为智能体）通过与环境的交互，根据获得的“奖励”或“惩罚”来调整自己的行为策略。\n    *   **数据形式**：行动 + 环境反馈（奖励/惩罚）。\n    *   **目标**：学习出一套能获得最大累积奖励的最优策略。\n    *   **例子**：\n        *   **AlphaGo** 通过与自己下棋，赢了得正奖励，输了得负奖励，从而学习出高超的棋艺。\n        *   **自动驾驶汽车**，安全行驶获得正奖励，发生碰撞获得负奖励。\n\n---\n\n### 机器学习的常见应用\n\n机器学习已经渗透到我们生活的方方面面：\n\n*   **推荐系统**： Netflix、淘宝、抖音的个性化推荐。\n*   **图像识别**： 人脸解锁、医疗影像（识别肿瘤）、自动驾驶（识别行人和车辆）。\n*   **自然语言处理**： 智能客服、语音助手（Siri、小爱同学）、机器翻译。\n*   **金融风控**： 信用卡欺诈检测、贷款信用评估。\n*   **搜索引擎**： Google、百度的搜索结果排序。\n\n### 总结\n\n**机器学习本质上是一种从经验中学习的能力。** 它让计算机不再仅仅是执行命令的工具，而是成为了能够从海量数据中发现规律、做出预测和决策的“智能体”。它是当今人工智能浪潮的核心驱动力，正在深刻地改变着世界。\n\n希望这个解释能帮助你理解什么是机器学习！',
#  'usage': {'prompt_tokens': 13,
#   'completion_tokens': 1033,
#   'total_tokens': 1046},
#  'model': 'deepseek-chat',
#  'finish_reason': 'stop'}

# %% [markdown]
# **流式处理**

# %%
import openai
from openai import OpenAI
import asyncio
from typing import List, Dict, Any, Generator, AsyncGenerator
import os
from dotenv import load_dotenv

# 加载环境变量
load_dotenv()
    
class DeepSeekClient:
    def __init__(self, api_key: str = None):
        # 如果没有提供 api_key，从环境变量中获取
        if api_key is None:
            api_key = os.environ.get('DEEPSEEK_API_KEY')

        self.client = OpenAI(
            api_key=api_key,
            base_url="https://api.deepseek.com"
        )
        self.async_client = openai.AsyncOpenAI(
            api_key=api_key,
            base_url="https://api.deepseek.com"
        )

    def chat_completion(self, messages: List[Dict], model: str = "deepseek-chat"):
        """同步聊天完成"""
        try:
            response = self.client.chat.completions.create(
                model=model,
                messages=messages,
                temperature=0.7,
                max_tokens=2000,
                top_p=1.0,
                frequency_penalty=0.0,
                presence_penalty=0.0
            )

            return {
                "content": response.choices[0].message.content,
                "usage": {
                    "prompt_tokens": response.usage.prompt_tokens,
                    "completion_tokens": response.usage.completion_tokens,
                    "total_tokens": response.usage.total_tokens
                },
                "model": response.model,
                "finish_reason": response.choices[0].finish_reason
            }

        except openai.RateLimitError as e:
            return {"error": "rate_limit", "message": str(e)}
        except openai.AuthenticationError as e:
            return {"error": "auth", "message": str(e)}
        except Exception as e:
            return {"error": "general", "message": str(e)}

    async def async_chat_completion(self, messages: List[Dict], model: str = "deepseek-chat"):
        """异步聊天完成"""
        try:
            response = await self.async_client.chat.completions.create(
                model=model,
                messages=messages,
                temperature=0.7,
                max_tokens=2000
            )

            return {
                "content": response.choices[0].message.content,
                "usage": dict(response.usage),
                "model": response.model
            }

        except Exception as e:
            return {"error": str(e)}

    def stream_chat_completion(self, messages: List[Dict], model: str = "deepseek-chat") -> Generator[str, None, None]:
        """生成器模式的流式输出"""
        try:
            stream = self.client.chat.completions.create(
                model=model,
                messages=messages,
                stream=True,
                temperature=0.7
            )
            
            for chunk in stream:
                if chunk.choices[0].delta.content is not None:
                    yield chunk.choices[0].delta.content
        
        except Exception as e:
            yield f"Error: {str(e)}"
    
    def stream_with_callback(self, messages: List[Dict], callback_func, model: str = "deepseek-chat"):
        """回调模式的流式输出"""
        full_response = ""
        
        try:
            stream = self.client.chat.completions.create(
                model=model,
                messages=messages,
                stream=True
            )
            
            for chunk in stream:
                if chunk.choices[0].delta.content is not None:
                    content = chunk.choices[0].delta.content
                    full_response += content
                    
                    # 调用回调函数
                    callback_func(
                        chunk_content=content,
                        full_content=full_response,
                        chunk_data=chunk
                    )
        
        except Exception as e:
            callback_func(error=str(e))
        
        return full_response
    
    async def async_stream_completion(self, messages: List[Dict], model: str = "deepseek-chat") -> AsyncGenerator[str, None]:
        """异步流式输出"""
        try:
            stream = await self.async_client.chat.completions.create(
                model=model,
                messages=messages,
                stream=True
            )
            
            async for chunk in stream:
                if chunk.choices[0].delta.content is not None:
                    yield chunk.choices[0].delta.content
        
        except Exception as e:
            yield f"Error: {str(e)}"


# ==================== 使用示例 ====================

if __name__ == "__main__":
    # 创建客户端
    client = DeepSeekClient()

    print("=" * 50)
    print("1. 同步调用示例")
    print("=" * 50)
    response = client.chat_completion([
        {"role": "system", "content": "你是一个有用的AI助手。"},
        {"role": "user", "content": "用一句话解释什么是机器学习"}
    ])
    print(response)
    print()
        
    # print("=" * 50)
    # print("2. 流式输出示例（生成器模式）")
    # print("=" * 50)
    # messages = [{"role": "user", "content": "写一首关于春天的诗"}]
    # print("流式输出开始：")
    # for chunk in client.stream_chat_completion(messages):
    #     print(chunk, end='', flush=True)
    # print("\n")

    # print("=" * 50)
    # print("3. 流式输出示例（回调模式）")
    # print("=" * 50)
    # def on_stream_chunk(chunk_content=None, full_content=None, chunk_data=None, error=None):
    #     if error:
    #         print(f"错误: {error}")
    #     else:
    #         print(chunk_content, end='', flush=True)

    # messages = [{"role": "user", "content": "介绍Python的三个优势"}]
    # print("回调模式流式输出：")
    # full_text = client.stream_with_callback(messages, on_stream_chunk)
    # print("\n")

    # print("=" * 50)
    # print("4. 异步调用示例")
    # print("=" * 50)
    # async def async_example():
    #     response = await client.async_chat_completion([
    #         {"role": "user", "content": "什么是深度学习？"}
    #     ])
    #     print("异步调用结果:")
    #     print(response)

    # asyncio.run(async_example())
    # print()

    # print("=" * 50)
    # print("5. 异步流式输出示例")
    # print("=" * 50)
    # async def async_stream_example():
    #     messages = [{"role": "user", "content": "列举5个编程语言"}]
    #     print("异步流式输出：")
    #     async for chunk in client.async_stream_completion(messages):
    #         print(chunk, end='', flush=True)
    #     print()

    # asyncio.run(async_stream_example())
# Out:
# ==================================================
# 1. 同步调用示例
# ==================================================
# {'content': '机器学习是让计算机通过数据自动学习和改进，而无需显式编程的方法。', 'usage': {'prompt_tokens': 15, 'completion_tokens': 17, 'total_tokens': 32}, 'model': 'deepseek-chat', 'finish_reason': 'stop'}

# %% [markdown]
# **同步调用**

# %%
import time

def sync_example():
    # client = DeepSeekClient()
    
    questions = [
        "什么是机器学习？",
        "什么是深度学习？",
        "什么是神经网络？"
    ]
    
    start = time.time()
    results = []
    
    # 一个一个执行，必须等待
    for question in questions:
        response = client.chat_completion([
            {"role": "user", "content": question}
        ])
        results.append(response)
        print(f"完成问题：{question}")
    
    print(f"总耗时：{time.time() - start:.1f} 秒")
    return results

sync_example()
# 输出：
# 完成问题：什么是机器学习？  (3秒后)
# 完成问题：什么是深度学习？  (6秒后)
# 完成问题：什么是神经网络？  (9秒后)
# 总耗时：9.0 秒
# Out:
# 完成问题：什么是机器学习？
# 完成问题：什么是深度学习？
# 完成问题：什么是神经网络？
# 总耗时：141.3 秒
# [{'content': '当然，很高兴为您解释什么是机器学习！\n\n这是一个非常核心且重要的问题。我们可以用一个简单的比喻开始，然后深入细节。\n\n### 一句话概括\n\n**机器学习是让计算机通过数据学习并自动改进的一种方法，而无需进行明确的程序编码。**\n\n---\n\n### 一个生动的比喻：教孩子识别猫\n\n想象一下，你要教一个从未见过猫的孩子什么是“猫”。\n\n1.  **传统编程方法**：你会给他一本规则手册，上面写着：“猫有尖耳朵、胡须、一条长尾巴、毛茸茸的身体...”。但这个方法很脆弱，如果遇到一只没有尾巴的猫（比如曼岛猫），孩子就认不出来了。\n\n2.  **机器学习方法**：你不会给他规则，而是给他**成百上千张**不同猫的图片（有各种品种、姿势、颜色），并告诉他“这些都是猫”。同时，也给他一些不是猫的图片（比如狗、汽车、树），并告诉他“这些不是猫”。通过看大量的例子，孩子的大脑会**自动发现**和**总结**出“猫”所共有的复杂特征（比如脸型、眼睛的形状、毛发的纹理等）。最终，当他看到一张新的、从未见过的猫的图片时，他也能正确地识别出来。\n\n在这个比喻中：\n*   **孩子** = 机器学习模型\n*   **大量的猫/非猫图片** = **数据**\n*   **“这是猫” / “这不是猫”的标签** = **答案/标签**\n*   **学习过程** = **训练**\n*   **识别新图片的能力** = **预测/推理**\n\n---\n\n### 机器学习的核心组成部分\n\n任何一个机器学习系统都包含三个基本要素：\n\n1.  **数据**：这是学习的“燃料”。数据可以是图片、文本、数字、传感器读数等等。数据的数量和质量通常直接决定模型性能的好坏。\n2.  **模型**：这是一个数学函数或一套算法，它负责从数据中找出规律。你可以把它看作一个“学生”。\n3.  **学习算法**：这是一套指令，告诉模型如何根据数据来调整其内部的参数，从而不断减少错误，提高预测准确性。\n\n---\n\n### 主要的机器学习类型\n\n机器学习主要分为三大类：\n\n#### 1. 监督学习\n这是最常见的一种类型。我们给模型提供**带有标签的数据**。\n*   **目标**：学习从输入到输出的映射关系。\n*   **例子**：\n    *   **分类**：预测离散的类别。比如，根据邮件内容判断是“垃圾邮件”还是“正常邮件”；根据肿瘤特征判断是“良性”还是“恶性”。\n    *   **回归**：预测连续的数值。比如，根据房屋面积、地段预测房价；根据历史数据预测明天的气温。\n\n#### 2. 无监督学习\n我们给模型提供**没有标签的数据**。\n*   **目标**：发现数据中内在的结构或模式。\n*   **例子**：\n    *   **聚类**：将客户根据购买行为分成不同的群组，以便进行精准营销。\n    *   **降维**：将高维数据（如几万个基因的表达量）压缩到低维空间进行可视化。\n\n#### 3. 强化学习\n模型作为一个**智能体**，通过与环境互动来学习。\n*   **目标**：学习一系列行动，以最大化累积奖励。\n*   **过程**：智能体采取一个行动，环境会反馈一个“奖励”或“惩罚”，智能体据此调整策略。\n*   **例子**：AlphaGo 学习下围棋、机器人学习走路、自动驾驶汽车学习如何安全行驶。\n\n---\n\n### 为什么机器学习现在如此重要？\n\n机器学习并非全新概念，但其在近年来的爆发主要得益于：\n*   **海量数据的产生**（互联网、物联网）。\n*   **强大的计算能力**（特别是GPU）。\n*   **先进的算法**（尤其是深度学习）。\n\n### 现实世界中的应用\n\n机器学习已经无处不在：\n*   **推荐系统**：Netflix、淘宝、抖音的个性化推荐。\n*   **图像识别**：人脸解锁、医疗影像分析（识别癌细胞）。\n*   **自然语言处理**：智能客服、语音助手（Siri、小爱同学）、机器翻译。\n*   **自动驾驶**：感知周围环境并做出决策。\n*   **金融风控**：检测信用卡欺诈交易。\n\n### 总结\n\n简单来说，**机器学习是人工智能的一个实现途径**。它颠覆了传统“人编规则，计算机执行”的模式，转变为“计算机从数据中自己总结规则，并不断优化”。它是一种让计算机获得“学习能力”的强大工具，正在深刻地改变着我们生活的方方面面。',
#   'usage': {'prompt_tokens': 7, 'completion_tokens': 957, 'total_tokens': 964},
#   'model': 'deepseek-chat',
#   'finish_reason': 'stop'},
#  {'content': '当然，很高兴为您解释深度学习。\n\n这是一个关于深度学习的全面介绍，从核心概念到实际应用。\n\n### 一、核心定义：一句话说清楚\n\n**深度学习是机器学习的一个分支，它试图模仿人脑的工作原理，通过一种叫做“人工神经网络”的模型，尤其是具有多个隐藏层的“深度”神经网络，来学习和识别数据中的复杂模式。**\n\n我们可以把它拆解开来理解：\n\n*   **“深度”**：指的是神经网络的**层数很多**。一个典型的深度学习网络可能有几十层、几百层甚至上千层。这些层就像一个复杂的过滤系统，每一层都从数据中提取不同级别或抽象程度的特征。\n*   **“学习”**：指的是模型通过分析**大量数据**来自动调整内部数百万甚至数十亿的**参数（权重和偏置）**，从而学会完成特定任务（如识别猫的图片）。它不需要人类为每个问题手动编写规则。\n\n---\n\n### 二、一个生动的比喻：如何教电脑认猫？\n\n想象一下你要教一个从没见过猫的孩子什么是“猫”。\n\n1.  **传统编程方法**：你需要编写一套详细的规则手册：“猫有尖耳朵、胡须、椭圆形的眼睛、毛茸茸的尾巴……” 这种方法非常费力，而且遇到无毛猫或折耳猫时，规则就可能失效。\n\n2.  **机器学习方法**：你给孩子看很多图片，并告诉他哪些是猫，哪些不是。孩子的大脑会自己总结出猫的特征。但你可能还需要手动告诉孩子“请重点关注耳朵和胡须的形状”，这叫做“特征工程”。\n\n3.  **深度学习方法**：你直接把成千上万张猫和非猫的图片“喂”给一个深度神经网络。\n    *   **第一层神经元**可能会识别最基础的边缘和像素点。\n    *   **第二层**可能会将这些边缘组合成简单的形状，比如圆形或三角形。\n    *   **第三层**可能会识别出更复杂的部件，如眼睛、鼻子、耳朵。\n    *   **更深的层**会将这些东西组合起来，形成“猫脸”或“猫身”的概念。\n    *   **最终**，网络自己会学会判断一张图片里是否有猫，而**你完全不需要告诉它应该关注耳朵还是尾巴**。它自己会发现哪些特征最重要。\n\n这个过程就是“端到端学习”：输入原始数据，直接输出结果，中间的特征提取过程完全由机器自动完成。\n\n---\n\n### 三、关键技术：神经网络\n\n深度学习的基础是人工神经网络，其核心结构包括：\n\n*   **神经元**：网络的基本单元，接收输入，进行简单计算，然后产生输出。\n*   **层**：\n    *   **输入层**：接收原始数据（如图像的像素）。\n    *   **隐藏层**：位于输入和输出层之间，负责特征提取和转换。“深度”就体现在这里有很多隐藏层。\n    *   **输出层**：输出最终结果（如“是猫”或“不是猫”）。\n*   **连接与权重**：层与层之间的神经元相互连接，每个连接都有一个**权重**。这个权重代表了该连接的重要性。学习的过程就是不断调整这些权重的过程。\n*   **激活函数**：决定一个神经元是否应该被“激活”并传递信号。它为网络引入了非线性，使其能够学习复杂的模式。\n\n---\n\n### 四、为什么深度学习现在如此强大？\n\n深度学习概念在上世纪就已提出，但直到近十几年才迎来爆发，主要得益于三大要素：\n\n1.  **大数据**：互联网产生了海量的标注数据（如ImageNet数千万张带标签的图片），为训练复杂的深度学习模型提供了“燃料”。\n2.  **强大算力**：特别是**GPU**的大规模使用。GPU最初为图形处理设计，其并行计算能力非常适合神经网络的大量矩阵运算，使得训练深层网络在时间上变得可行。\n3.  **算法创新**：研究人员提出了更有效的网络结构（如CNN、RNN、Transformer）和训练技巧，解决了深层网络训练中的梯度消失等问题。\n\n---\n\n### 五、主要应用领域\n\n深度学习已经渗透到我们生活的方方面面：\n\n*   **计算机视觉**：\n    *   **图像分类**：识别图片中的物体（Google Photos， 自动驾驶）。\n    *   **目标检测**：在图片中框出特定物体（人脸识别、车辆检测）。\n    *   **图像生成**：根据文本描述生成图片（DALL-E, Midjourney）。\n*   **自然语言处理**：\n    *   **机器翻译**：Google Translate, DeepL。\n    *   **语音识别与合成**：Siri, Alexa, 智能音箱。\n    *   **聊天机器人**：ChatGPT， 客服机器人。\n    *   **情感分析**：分析评论的正负面情绪。\n*   **自动驾驶**：感知周围环境、识别行人、车辆和交通标志。\n*   **医疗健康**：从医学影像（X光、CT）中辅助诊断疾病。\n*   **推荐系统**：Netflix， Amazon， TikTok 的个性化内容推荐。\n\n---\n\n### 六、总结：优缺点\n\n**优点**：\n*   **高性能**：在许多任务上达到了远超传统方法的准确率。\n*   **自动特征工程**：无需人工设计特征，能从原始数据中自动学习。\n*   **通用性强**：同样的技术可以应用于图像、文本、声音等不同领域。\n\n**缺点与挑战**：\n*   **需要大量数据**：训练一个有效的模型通常需要海量标注数据。\n*   **计算成本高**：训练过程需要强大的GPU集群，耗时耗电。\n*   **“黑箱”问题**：模型的决策过程不透明，难以解释为什么它会做出某个特定判断。\n*   **可能产生偏见**：如果训练数据本身存在偏见，模型也会学会并放大这些偏见。\n\n希望这个解释能帮助您全面理解深度学习！它是一个强大且正在快速发展的技术，正在深刻地改变着我们与世界交互的方式。',
#   'usage': {'prompt_tokens': 7,
#    'completion_tokens': 1234,
#    'total_tokens': 1241},
#   'model': 'deepseek-chat',
#   'finish_reason': 'stop'},
#  {'content': '当然！这是一个关于神经网络的详细解释，从简单类比到核心概念，希望能让你彻底明白。\n\n---\n\n### 一、核心思想：模仿大脑\n\n神经网络，顾名思义，是受到**人脑神经网络**的启发而设计出来的计算模型。\n\n你可以把大脑想象成一个由数十亿个神经元相互连接构成的巨大网络。每个神经元通过树突接收来自其他神经元的信号，进行处理，然后通过轴突将信号传递给下一个神经元。当无数个简单的神经元以复杂的方式连接和协作时，就产生了智能、思想和意识。\n\n人工神经网络的目标就是用软件或硬件来模拟这个过程，解决复杂的任务。\n\n### 二、一个简单的比喻：认猫\n\n假设我们想教一个神经网络“认猫”。我们不会直接告诉它猫的规则（比如有胡子、尖耳朵），而是通过大量“练习”让它自己学会。\n\n1.  **输入层：** 就像你的眼睛。你给网络看一张图片，图片的每个像素点（可能是红、绿、蓝的数值）就是输入层的一个“神经元”。\n2.  **隐藏层：** 就像你的大脑视觉皮层。这是网络“思考”的地方。\n    *   第一层隐藏层的神经元可能会识别非常基础的特征，比如**边缘、角落**。\n    *   第二层的神经元接收第一层的信号，组合起来识别更复杂的特征，比如**眼睛的形状、毛发的纹理**。\n    *   更深层的神经元会组合这些复杂特征，最终形成“猫脸”、“猫的身体”等更抽象的概念。\n3.  **输出层：** 就像你做出判断。经过隐藏层的层层处理，信息最终到达输出层。输出层可能只有一个神经元，它的数值代表“这张图是猫的概率”。比如，输出0.95，就意味着网络有95%的把握认为这是猫。\n\n**连接是关键：** 每一层的神经元都与下一层的所有（或部分）神经元相连。这些连接上都有一个**权重**。权重就像这个连接的重要性或强度。\n\n### 三、神经网络是如何“学习”的？\n\n学习的过程，就是**自动调整数百万个连接权重**的过程，目的是让网络的输出结果越来越接近正确答案。\n\n这个过程主要包含两个核心步骤：\n\n1.  **前向传播：**\n    *   输入一张猫的图片。\n    *   数据从输入层开始，经过每一层时，与权重进行计算，并通过一个叫“**激活函数**”的部件（决定这个神经元是否应该被“激活”或触发），最终得到输出结果（比如，输出0.3，即30%认为是猫）。\n\n2.  **反向传播 + 梯度下降：**\n    *   将网络的输出（0.3）与真实答案（1，代表是猫）进行比较，计算出一个**损失**（也叫误差）。这里的损失很大，因为0.3离1很远。\n    *   这个误差信号会**从输出层反向传播回网络**。\n    *   在反向传播的过程中，网络会计算出每个权重对总误差应负多少“责任”。\n    *   然后，使用一种叫**梯度下降**的优化算法，根据这个“责任”大小，对所有的权重进行微调，目标是让总误差减小。\n    *   **打个比方：** 就像调节一个有很多旋钮的老式收音机来寻找清晰的信号。你先拧一下（前向传播），听听杂音多大（计算损失），然后根据杂音的变化，决定每个旋钮该往哪个方向、拧多大（反向传播），再拧一次（更新权重）。重复这个过程，直到杂音最小，信号最清晰。\n\n通过给网络展示**成千上万张**猫和非猫的图片，并重复以上过程数百万次，网络中的权重就会被调整到最佳状态，从而成为一个优秀的“猫识别器”。\n\n### 四、关键组成部分\n\n*   **神经元：** 接收输入，进行加权求和，再通过激活函数产生输出。\n*   **权重 & 偏置：** 模型需要学习的核心参数，决定了输入信号的影响力。\n*   **激活函数：** 为网络引入非线性因素，使其能够学习复杂模式。没有它，神经网络就只是一个简单的线性回归模型。常见的激活函数有：Sigmoid, ReLU等。\n*   **损失函数：** 衡量模型输出与真实答案的差距。\n*   **优化器：** 执行梯度下降算法的具体方式，用于更新权重。\n\n### 五、为什么神经网络如此强大？\n\n1.  **自动特征工程：** 传统机器学习需要专家手动设计特征（比如“眼睛的周长”），而神经网络能**自动从原始数据中学习**出相关的特征层次。\n2.  **处理复杂问题：** 只要有足够的数据和计算资源，深度学习模型能够解决极其复杂的问题，如图像识别、自然语言处理、语音合成、下围棋等，其性能往往超过传统方法。\n3.  **通用近似定理：** 理论上，一个足够大的神经网络可以**近似任何复杂的函数**，这意味着它可以模拟极其复杂的输入-输出关系。\n\n### 六、主要类型和应用\n\n*   **卷积神经网络（CNN）：** 专为处理图像数据设计，在图像识别、分类、目标检测等领域是绝对的主流。\n*   **循环神经网络（RNN）：** 专为处理序列数据设计（如文本、语音、时间序列），能够记住之前的信息。常用于机器翻译、语音识别。\n*   **Transformer：** 当前最流行的架构，通过“自注意力机制”处理序列，效果和效率都远超RNN。GPT、BERT等大型语言模型都基于Transformer。\n\n### 总结\n\n简单来说，**神经网络是一个通过模仿人脑结构，通过大量数据来自动学习输入和输出之间复杂关系的强大数学模型。它的核心在于通过“前向传播”和“反向传播”来不断调整内部数百万个连接参数，从而完成特定的智能任务。**\n\n它就像一个万能函数拟合器，通过数据驱动的方式，学会了我们难以用显式规则编程的复杂技能。',
#   'usage': {'prompt_tokens': 7,
#    'completion_tokens': 1238,
#    'total_tokens': 1245},
#   'model': 'deepseek-chat',
#   'finish_reason': 'stop'}]

# %% [markdown]
# **异步调用**

# %%
import asyncio
import time

async def async_example():
    # client = DeepSeekClient()
    
    questions = [
        "什么是机器学习？",
        "什么是深度学习？",
        "什么是神经网络？"
    ]
    
    start = time.time()
    
    # 同时发送所有请求
    tasks = [
        client.async_chat_completion([
            {"role": "user", "content": q}
        ])
        for q in questions
    ]
    
    # 等待所有请求完成
    results = await asyncio.gather(*tasks)
    
    print(f"总耗时：{time.time() - start:.1f} 秒")
    return results

await  async_example()

# 输出：
# 总耗时：3.0 秒  (3个请求并发执行！)
# Out:
# 总耗时：63.2 秒
# [{'content': '当然，这是一个关于机器学习的清晰解释。\n\n### 一句话概括\n\n**机器学习是人工智能的一个分支，其核心是让计算机通过数据“学习”规律，而不是通过明确的程序指令来完成特定任务。**\n\n---\n\n### 一个生动的比喻\n\n想象一下教一个孩子识别猫。\n\n*   **传统编程**：你需要给他一本详细的规则手册，比如“有尖耳朵、胡须、一条长尾巴、毛茸茸的……”。如果遇到一只无毛猫，这个规则就失效了。\n*   **机器学习**：你给孩子看成千上万张不同猫的图片（有橘猫、黑猫、白猫、胖猫、瘦猫），并告诉他“这些都是猫”。通过看大量的例子，孩子的大脑会自己总结出“猫”的共同特征。之后，当他看到一张从未见过的猫图片时，他也能认出这是一只猫。\n\n在机器学习中，**计算机就是这个“孩子”**，**海量的数据就是那些“猫的图片”**，而**学习出来的“规律”就是那个识别猫的模型**。\n\n---\n\n### 机器学习的核心三要素\n\n1.  **数据**\n    *   这是机器学习的基础燃料。数据可以是数字、文本、图片、音频等。数据的数量和质量直接决定了模型性能的上限。俗话说“垃圾进，垃圾出”。\n\n2.  **模型**\n    *   模型可以理解为一个数学函数或一套算法。它负责从数据中找出规律。学习的过程，就是不断调整这个函数的内部参数，使其能最好地拟合数据。\n\n3.  **算法**\n    *   算法是调整模型参数的具体方法和步骤。不同的学习任务（如预测、分类）会使用不同的算法（如决策树、神经网络、支持向量机等）。\n\n---\n\n### 主要的学习方式\n\n机器学习主要分为三大类：\n\n1.  **监督学习**\n    *   **特点**：数据是带有“标签”的。就像有答案的学习资料。\n    *   **过程**：给计算机提供大量的“输入数据”和对应的“正确答案”（标签），让它学习两者之间的映射关系。\n    *   **主要任务**：\n        *   **分类**：预测一个类别。例如，根据邮件内容判断是“垃圾邮件”还是“正常邮件”；根据肿瘤特征判断是“良性”还是“恶性”。\n        *   **回归**：预测一个数值。例如，根据房屋面积、地段预测房价；根据历史数据预测明天的气温。\n\n2.  **无监督学习**\n    *   **特点**：数据是**没有标签**的。就像给计算机一堆没有分类的杂物，让它自己发现其中的结构。\n    *   **过程**：算法自行探索数据的内在模式或分组。\n    *   **主要任务**：\n        *   **聚类**：将数据自动分成不同的组。例如，根据客户行为对客户进行分群，以便精准营销；对文章主题进行聚类。\n        *   **降维**：在保留主要信息的前提下，减少数据的维度，便于可视化或后续处理。\n\n3.  **强化学习**\n    *   **特点**：像一个通过“试错”学习的孩子。算法（智能体）通过与环境互动，根据行动带来的奖励或惩罚来学习最优策略。\n    *   **过程**：智能体执行一个动作，环境会反馈一个状态和奖励（正奖励或负惩罚），智能体的目标是学习一套策略，使得长期累积的奖励最大化。\n    *   **典型应用**：AlphaGo（下围棋）、机器人控制、自动驾驶。\n\n---\n\n### 现实生活中的例子\n\n*   **推荐系统**：你在 Netflix、淘宝 或 YouTube 上看到的“猜你喜欢”，都是监督学习和协同过滤的经典应用。\n*   **语音助手**：Siri、小爱同学等，使用机器学习来识别你的语音指令。\n*   **人脸识别**：手机解锁、支付宝支付，背后是复杂的深度学习模型。\n*   **医疗诊断**：通过分析医学影像（如X光片、MRI）来辅助医生发现病灶。\n*   **自动驾驶**：通过分析摄像头和传感器数据，来识别行人、车辆和交通标志。\n\n### 总结\n\n简单来说，**机器学习是一种从数据中自动分析和提取模式，并利用这些模式对未知数据进行预测或决策的技术。** 它是当今人工智能浪潮背后的核心驱动力，正在深刻地改变着我们生活的方方面面。',
#   'usage': {'completion_tokens': 900,
#    'prompt_tokens': 7,
#    'total_tokens': 907,
#    'completion_tokens_details': None,
#    'prompt_tokens_details': PromptTokensDetails(audio_tokens=None, cached_tokens=0),
#    'prompt_cache_hit_tokens': 0,
#    'prompt_cache_miss_tokens': 7},
#   'model': 'deepseek-chat'},
#  {'content': '当然，很乐意为您解释什么是深度学习。\n\n这是一个从简单到详细的解释，您可以根据自己的背景选择阅读。\n\n### 一句话概括\n\n**深度学习是机器学习的一个分支，它试图模仿人脑的工作原理，通过一种叫做“人工神经网络”的模型，尤其是多层的“深度”网络，来学习和识别数据中的复杂模式。**\n\n---\n\n### 生动的比喻：一个婴儿如何学会识别猫\n\n想象一下教一个婴儿什么是“猫”：\n\n1.  **第一层学习**：你指着猫说“这是猫”。婴儿最初只看到一些**基础特征**：有毛、有尾巴、尖耳朵。\n2.  **第二层学习**：大脑将这些基础特征组合起来，形成更**复杂的特征**：比如“毛茸茸的脸部轮廓”和“一条长尾巴”。\n3.  **更深层的学习**：再往上一层，大脑将这些复杂特征组合成**抽象概念**：“一个有着特定脸型、身体结构和行为的物体”。\n4.  **最终输出**：经过多次看到不同的猫，大脑最终形成了一个关于“猫”的**高度抽象模型**。之后，即使看到一只它从未见过的猫，它也能大概率认出来。\n\n**深度学习模型就是这个过程的数字化版本。** 它的“深度”指的就是网络中包含很多这样的“层”，每一层都在前一层的输出基础上，学习更复杂、更抽象的特征。\n\n---\n\n### 核心概念与技术原理\n\n1.  **人工神经网络**\n    *   这是深度学习的基础。它由大量互连的**节点**（也称为“神经元”）组成，这些节点分层排列。\n    *   **输入层**：接收原始数据（如图像的像素、一段文字的单词）。\n    *   **隐藏层**：位于输入和输出层之间，可以有一层或多层。**“深度”学习中的“深度”就指的是有很多隐藏层**。每一层都会对数据进行一种数学变换。\n    *   **输出层**：给出最终的结果（如“这是猫”或“这是狗”）。\n\n2.  **“学习”是如何发生的？**\n    *   **前向传播**：数据从输入层进入，经过隐藏层的一系列计算，最终得到输出层的预测结果。\n    *   **计算误差**：将预测结果与真实答案（比如图片的标签“猫”）进行比较，计算出误差。\n    *   **反向传播**：这是学习的核心。将误差从输出层向输入层反向传播，并利用这个误差来调整网络中每一个连接的**权重**。\n    *   **权重调整**：权重决定了某个神经元对下一个神经元的影响程度。通过不断调整这些权重，整个网络逐渐“学会”了如何将输入数据（像素）准确地映射到输出结果（标签）。这个过程需要海量的数据和强大的计算能力。\n\n---\n\n### 深度学习为什么如此强大？\n\n与传统机器学习方法相比，深度学习的优势在于：\n\n*   **自动特征工程**：传统方法需要人类专家来设计和提取数据的特征（比如，告诉计算机“猫有胡须”）。而深度学习可以**自动从原始数据中学习到最相关的特征**，省去了大量的人工工作，并且通常能发现人类难以设计的复杂特征。\n*   **处理非结构化数据能力极强**：它在图像、视频、音频、文本等非结构化数据上表现尤为出色。\n*   **随着数据量增加，性能持续提升**：传统的机器学习模型在数据量达到一定程度后性能会趋于平缓，而深度模型通常能利用更多的数据持续提升性能。\n\n---\n\n### 主要应用领域\n\n深度学习已经渗透到我们生活的方方面面：\n\n*   **计算机视觉**：\n    *   **图像分类与识别**：照片自动分类、人脸识别。\n    *   **目标检测**：自动驾驶中识别行人、车辆。\n    *   **图像生成**：AI绘画（如Stable Diffusion, Midjourney）。\n*   **自然语言处理**：\n    *   **机器翻译**：Google翻译。\n    *   **智能助手**：Siri, Alexa, 小爱同学。\n    *   **聊天机器人**：ChatGPT。\n    *   **情感分析**：分析评论是正面还是负面。\n*   **语音识别与合成**：语音转文字、智能音箱、虚拟人的语音。\n*   **推荐系统**：Netflix、淘宝、抖音的个性化内容推荐。\n*   **自动驾驶**：感知周围环境，做出驾驶决策。\n*   **医疗健康**：从医学影像（X光、CT）中辅助诊断疾病。\n\n---\n\n### 挑战与局限\n\n尽管强大，深度学习也有其局限性：\n\n*   **需要大量数据**：训练一个有效的深度模型通常需要成千上万甚至百万计的标注数据。\n*   **计算资源昂贵**：训练过程需要强大的GPU，耗时且耗电。\n*   **“黑箱”问题**：模型的决策过程非常复杂，难以解释为什么它会做出某个特定的判断，这在医疗、金融等需要高可靠性和可解释性的领域是一个问题。\n*   **可能产生偏见**：如果训练数据本身存在偏见（例如，主要包含某一种肤色的人脸），模型也会学会并放大这种偏见。\n\n### 总结\n\n总而言之，**深度学习是一种通过构建深层的神经网络，让机器能够从海量数据中自动学习复杂模式和特征的强大技术**。它是当前人工智能浪潮的核心驱动力，正在深刻地改变着科技和社会的面貌。\n\n希望这个解释能帮助您理解深度学习！如果您对某个具体应用（比如ChatGPT或AI绘画）感兴趣，我们可以继续深入探讨。',
#   'usage': {'completion_tokens': 1142,
#    'prompt_tokens': 7,
#    'total_tokens': 1149,
#    'completion_tokens_details': None,
#    'prompt_tokens_details': PromptTokensDetails(audio_tokens=None, cached_tokens=0),
#    'prompt_cache_hit_tokens': 0,
#    'prompt_cache_miss_tokens': 7},
#   'model': 'deepseek-chat'},
#  {'content': '当然！这是一个关于神经网络的详细解释，从核心概念到工作原理，再到应用和未来。\n\n### 一句话概括\n\n**神经网络是一种受人脑结构启发的计算模型，它能够从数据中学习复杂的模式，并用于预测、分类和决策。**\n\n---\n\n### 1. 核心思想：模仿人脑\n\n神经网络的基本思想是模仿生物大脑中神经元的工作方式。\n*   **生物神经元**：通过树突接收信号，在细胞体处理，如果信号足够强，就通过轴突传递给下一个神经元。\n*   **人工神经元（或节点/单元）**：是神经网络的基本构建块。\n\n### 2. 神经网络的基本结构\n\n一个典型的神经网络由三层组成：\n\n1.  **输入层**：\n    *   负责接收外部数据。\n    *   每个节点（神经元）代表数据的一个**特征**。例如，在图像识别中，每个特征可能是一个像素的数值；在预测房价时，特征可能是面积、位置、卧室数量等。\n\n2.  **隐藏层**：\n    *   位于输入层和输出层之间。\n    *   这是神经网络进行“思考”和“学习”的地方。\n    *   一个网络可以有多个隐藏层，层数越多，网络就越“深”（这也是“深度学习”一词的由来）。\n    *   每一层的神经元都会接收来自前一层所有神经元的输入，并进行计算。\n\n3.  **输出层**：\n    *   产生最终的预测或分类结果。\n    *   节点的数量取决于任务类型。例如：\n        *   **二分类问题**（如判断邮件是否为垃圾邮件）：1个节点（是/否）。\n        *   **多分类问题**（如识别图片中的动物是猫、狗还是鸟）：多个节点，每个节点对应一个类别。\n        *   **回归问题**（如预测房价）：1个节点，输出一个具体数值。\n\n**连接与权重**：\n*   层与层之间的神经元通过“**连接**”相连。\n*   每个连接都有一个“**权重**”，代表该连接的重要性。权重是可正可负的数值。\n*   **学习的过程，本质上就是调整这些权重的过程**，使得网络的预测越来越准确。\n\n---\n\n### 3. 神经网络如何工作与学习？\n\n我们通过一个简单的例子（判断图片是否是猫）来看神经网络的工作流程：\n\n**第一步：前向传播**\n1.  **输入**：一张猫的图片（像素数据）被送入输入层。\n2.  **加权求和**：隐藏层的每个神经元接收所有输入层节点的值，并将每个输入乘以对应的**权重**，然后求和。\n3.  **添加偏置**：在求和结果上加上一个**偏置**项，这类似于一个阈值，让模型更容易被激活。\n4.  **激活函数**：将加权求和并加上偏置的结果，输入到一个**激活函数**中。这个函数的作用是引入非线性，让网络能够学习更复杂的关系（而不仅仅是简单的线性关系）。常见的激活函数有Sigmoid、ReLU等。\n5.  经过隐藏层的计算后，信号最终传递到输出层。输出层可能使用Softmax等函数，将结果转换为概率（例如，是猫的概率为90%，是狗的概率为5%等）。\n\n**第二步：计算损失**\n*   将网络的输出（例如，“是猫的概率为80%”）与真实标签（“是猫，即100%”）进行比较。\n*   **损失函数**会计算出一个“**损失值**”，量化预测与真实的差距。差距越大，损失值越高。\n\n**第三步：反向传播 - 学习的核心！**\n*   这是神经网络最神奇的部分。网络会将损失值从输出层向输入层**反向传播**。\n*   在这个过程中，算法（如**梯度下降**）会计算出每个权重对总损失应负多少“责任”。\n*   然后，根据这个责任大小，以微小的步长**调整（更新）所有权重和偏置**，目标是降低下一次预测的损失值。\n\n**第四步：迭代**\n*   用海量的数据（成千上万张猫和非猫的图片）重复以上三个步骤成千上万次。\n*   每一次迭代，权重都在被微调，网络的预测能力也越来越强。最终，我们得到一个训练好的模型。\n\n---\n\n### 4. 为什么神经网络如此强大？\n\n1.  **自动特征工程**：传统机器学习需要专家手动设计和提取特征，而神经网络能自动从原始数据中学习到相关的特征。\n2.  **处理复杂非线性问题**：借助激活函数和多层结构，神经网络可以拟合极其复杂的、非线性的关系。\n3.  **对噪声的鲁棒性**：经过充分训练的网络对输入数据中的微小噪声或残缺不敏感。\n4.  **通用近似定理**：理论上，一个足够大的神经网络可以近似任何复杂的函数。\n\n---\n\n### 5. 主要类型与应用\n\n*   **卷积神经网络（CNN）**：专为处理网格状数据（如图像、视频）设计。在图像识别、医疗影像分析、自动驾驶等领域取得了革命性成功。\n*   **循环神经网络（RNN）**：专为处理序列数据（如文本、语音、时间序列）设计。适用于机器翻译、语音识别、文本生成等。其变体如LSTM和GRU更为常用。\n*   **生成对抗网络（GAN）**：由两个网络（生成器和判别器）相互“博弈”组成，可以生成极其逼真的新数据，如图像、音乐和视频。\n\n**应用领域几乎无处不在**：\n*   **计算机视觉**：人脸识别、图像分类、自动驾驶。\n*   **自然语言处理**：智能客服、机器翻译、搜索引擎、聊天机器人。\n*   **语音识别**：Siri、Alexa、Google Assistant。\n*   **推荐系统**：Netflix、Amazon、淘宝的商品和内容推荐。\n*   **游戏**：AlphaGo击败人类顶尖棋手。\n*   **金融**：欺诈检测、算法交易。\n\n---\n\n### 6. 挑战与未来\n\n*   **数据依赖**：需要大量高质量的标注数据进行训练。\n*   **计算资源**：训练大型网络需要强大的GPU/TPU，耗时耗能。\n*   **“黑箱”问题**：网络的决策过程难以解释，我们往往不知道它为何做出某个判断，这在医疗、金融等高风险领域是个问题。\n*   **过拟合**：模型在训练数据上表现完美，但在新数据上表现很差。\n\n**未来方向**包括可解释性AI、更高效的模型架构、小样本学习、降低能耗等。\n\n### 总结\n\n你可以把神经网络想象成一个**万能函数拟合器**。我们给它输入（X）和期望的输出（Y），它通过“学习”自动找到从X到Y的最复杂的映射关系。正是这种强大的学习能力，使其成为当今人工智能浪潮的核心驱动力。',
#   'usage': {'completion_tokens': 1430,
#    'prompt_tokens': 7,
#    'total_tokens': 1437,
#    'completion_tokens_details': None,
#    'prompt_tokens_details': PromptTokensDetails(audio_tokens=None, cached_tokens=0),
#    'prompt_cache_hit_tokens': 0,
#    'prompt_cache_miss_tokens': 7},
#   'model': 'deepseek-chat'}]

# %% [markdown]
# **同步调用/异步调用性能测试**

# %%
import time
import asyncio

# 测试函数
def test_sync():
    """同步调用测试"""
    client = DeepSeekClient()
    start = time.time()
    
    for i in range(5):
        client.chat_completion([
            {"role": "user", "content": f"问题 {i+1}"}
        ])
    
    print(f"同步调用 5 次耗时：{time.time() - start:.1f} 秒")

async def test_async():
    """异步调用测试"""
    client = DeepSeekClient()
    start = time.time()
    
    tasks = [
        client.async_chat_completion([
            {"role": "user", "content": f"问题 {i+1}"}
        ])
        for i in range(5)
    ]
    
    await asyncio.gather(*tasks)
    print(f"异步调用 5 次耗时：{time.time() - start:.1f} 秒")

# 运行测试
test_sync()           # 输出：同步调用 5 次耗时：15.0 秒
await test_async()  # 输出：异步调用 5 次耗时：3.0 秒
# Out:
# 同步调用 5 次耗时：222.7 秒
# 异步调用 5 次耗时：2.6 秒

# %%
await test_async()
# Out:
# 异步调用 5 次耗时：59.2 秒
