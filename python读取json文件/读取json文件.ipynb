# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import json

# %%
df = pd.read_json("补充特征.json").reset_index()

# %%
df_expanded = df.explode('data').reset_index(drop=True)
df_expanded = pd.concat([
    df_expanded.drop('data', axis=1),
    df_expanded['data'].apply(pd.Series)
], axis=1)

# %%
df_expanded_punish = df_expanded[df_expanded['index'] == 'punish']
df_expanded_punish
# Out:
#     index  success  status  code message   id  sceneCode            name  \
# 0  punish     True       1   200    操作成功  1.0        NaN  lastPunishTime
# 1  punish     True       1   200    操作成功  2.0        NaN    punishReason
#
#      absoluteName  relativeCode  ...      desc absoluteDesc              type  \
# 0  lastPunishTime           NaN  ...  最后一次处置时间     最后一次处置时间    java.util.Date
# 1    punishReason           NaN  ...      处置原因         处置原因  java.lang.String
#
#   itemType  nullable mustPresent fields channelId  variableClassification   0
# 0      NaN      None        None     []       NaN                  PUNISH NaN
# 1      NaN      None        None     []       NaN                  PUNISH NaN
#
# [2 rows x 21 columns]

# %%
df_expanded_appeal = df_expanded[df_expanded['index'] == 'appeal']
df_expanded_appeal
# Out:
#     index  success  status  code message   id  sceneCode  \
# 2  appeal     True       1   200    操作成功  1.0        NaN
# 3  appeal     True       1   200    操作成功  2.0        NaN
# 4  appeal     True       1   200    操作成功  3.0        NaN
# 5  appeal     True       1   200    操作成功  4.0        NaN
# 6  appeal     True       1   200    操作成功  5.0        NaN
#
#                        name              absoluteName  relativeCode  ...  \
# 2               firstAppeal               firstAppeal           NaN  ...
# 3      latestAppealAuditUrl      latestAppealAuditUrl           NaN  ...
# 4  latestAppealAuditOpinion  latestAppealAuditOpinion           NaN  ...
# 5             auditBillCode             auditBillCode           NaN  ...
# 6          auditBizBillCode          auditBizBillCode           NaN  ...
#
#            desc  absoluteDesc               type itemType  nullable  \
# 2        是否首次申诉        是否首次申诉  java.lang.Boolean      NaN      None
# ...

# %%
df_expanded_supplementFeature = df_expanded[df_expanded['index'] == 'supplementFeature']
df_expanded_supplementFeature
# Out:
#                 index  success  status  code message     id  sceneCode  \
# 7   supplementFeature     True       1   200    操作成功   30.0        NaN
# 8   supplementFeature     True       1   200    操作成功  152.0        NaN
# 9   supplementFeature     True       1   200    操作成功  166.0        NaN
# 10  supplementFeature     True       1   200    操作成功  163.0        NaN
# 11  supplementFeature     True       1   200    操作成功  164.0        NaN
#
#                                      name  \
# 7                        customerBaseInfo
# 8                         customerPoiInfo
# 9   relatedBuffaloCustomerTradeIndicators
# 10                relatedCustomerBaseInfo
# 11                 relatedCustomerPoiInfo
#
#                              absoluteName  relativeCode  ...  \
# 7                        customerBaseInfo           NaN  ...
# 8                         customerPoiInfo           NaN  ...
# 9   relatedBuffaloCustomerTradeIndicators           NaN  ...
# ...

# %%
# Out:
# ['customerBaseInfo',
#  'customerPoiInfo',
#  'relatedBuffaloCustomerTradeIndicators',
#  'relatedCustomerBaseInfo',
#  'relatedCustomerPoiInfo']

# %%
df_name_list = []
for name in df_expanded_supplementFeature['name'].tolist():
    var_name = f'df_expanded_supplementFeature_{name}'
    globals()[var_name] = df_expanded_supplementFeature[df_expanded_supplementFeature['name'] == name].reset_index(drop=True)
    globals()[var_name] = pd.DataFrame(globals()[var_name]['fields'][0])
    df_name_list.append(var_name)

# %%
df_expanded_supplementFeature_customerBaseInfo
# Out:
#      id sceneCode                  name  \
# 0   174      None                  bdId
# 1   176      None                bdName
# 2   175      None                  buId
# 3   177      None                cityId
# 4   178      None              cityName
# 5   172      None          customerName
# 6   170      None        customerStatus
# 7   171      None          customerType
# 8   485      None  formattedOfflineTime
# 9   510      None   formattedOnlineTime
# 10  191      None        hadBeenOffline
# 11  385      None              lockFlag
# 12  189      None       offlineReasonId
# 13  190      None           offlineTime
# 14  173      None             poiSource
# 15  580      None        receiptAddress
#
#                              absoluteName          relativeCode  \
# 0                   customerBaseInfo.bdId                  bdId
# 1                 customerBaseInfo.bdName                bdName
# 2                   customerBaseInfo.buId                  buId
# ...

# %%
df_expanded_supplementFeature_relatedBuffaloCustomerTradeIndicators
# Out:
#     id sceneCode                           name  \
# 0  548      None  formattedFirstArrangedOrdTime
# 1  547      None   formattedLastArrangedOrdTime
#
#                                         absoluteName  \
# 0  relatedBuffaloCustomerTradeIndicators.formatte...
# 1  relatedBuffaloCustomerTradeIndicators.formatte...
#
#                     relativeCode  \
# 0  formattedFirstArrangedOrdTime
# 1   formattedLastArrangedOrdTime
#
#                                 nullSafeAbsoluteName  \
# 0  relatedBuffaloCustomerTradeIndicators.?formatt...
# 1  relatedBuffaloCustomerTradeIndicators.?formatt...
#
#                         desc                                    absoluteDesc  \
# 0  首单时间（yyyy-MM-dd HH:mm:ss）  关联客户交易指标（来源于Buffalo）.首单时间（yyyy-MM-dd HH:mm:ss）
# 1  末单时间（yyyy-MM-dd HH:mm:ss）  关联客户交易指标（来源于Buffalo）.末单时间（yyyy-MM-dd HH:mm:ss）
#
#                type itemType  nullable  mustPresent fields channelId  \
# 0  java.lang.String     None      True        False     []      None
# ...

# %%
df_expanded_supplementFeature_relatedBuffaloCustomerTradeIndicators
# Out:
#     id sceneCode                           name  \
# 0  548      None  formattedFirstArrangedOrdTime
# 1  547      None   formattedLastArrangedOrdTime
#
#                                         absoluteName  \
# 0  relatedBuffaloCustomerTradeIndicators.formatte...
# 1  relatedBuffaloCustomerTradeIndicators.formatte...
#
#                     relativeCode  \
# 0  formattedFirstArrangedOrdTime
# 1   formattedLastArrangedOrdTime
#
#                                 nullSafeAbsoluteName  \
# 0  relatedBuffaloCustomerTradeIndicators.?formatt...
# 1  relatedBuffaloCustomerTradeIndicators.?formatt...
#
#                         desc                                    absoluteDesc  \
# 0  首单时间（yyyy-MM-dd HH:mm:ss）  关联客户交易指标（来源于Buffalo）.首单时间（yyyy-MM-dd HH:mm:ss）
# 1  末单时间（yyyy-MM-dd HH:mm:ss）  关联客户交易指标（来源于Buffalo）.末单时间（yyyy-MM-dd HH:mm:ss）
#
#                type itemType  nullable  mustPresent fields channelId  \
# 0  java.lang.String     None      True        False     []      None
# ...

# %%
df_expanded_supplementFeature_relatedCustomerBaseInfo
# Out:
#      id sceneCode                  name  \
# 0   546      None                  bdId
# 1   545      None                bdName
# 2   544      None                  buId
# 3   543      None                cityId
# 4   542      None              cityName
# 5   541      None          customerName
# 6   540      None        customerStatus
# 7   539      None          customerType
# 8   538      None  formattedOfflineTime
# 9   537      None   formattedOnlineTime
# 10  536      None        hadBeenOffline
# 11  535      None              lockFlag
# 12  534      None       offlineReasonId
# 13  533      None           offlineTime
# 14  532      None             poiSource
# 15  581      None        receiptAddress
#
#                                     absoluteName          relativeCode  \
# 0                   relatedCustomerBaseInfo.bdId                  bdId
# 1                 relatedCustomerBaseInfo.bdName                bdName
# ...

# %%
df_expanded_supplementFeature_relatedCustomerPoiInfo
# Out:
#      id sceneCode                        name  \
# 0   531      None                     address
# 1   530      None                      cityId
# 2   529      None                    cityName
# 3   528      None                    countyId
# 4   527      None                  countyName
# 5   526      None                facePhotoUrl
# 6   512      None  facePhotoUrlForDynamicForm
# 7   525      None                  firstCatId
# 8   524      None                firstCatName
# 9   523      None                   klPoiType
# 10  522      None                    latitude
# 11  521      None                   longitude
# 12  520      None                       poiId
# 13  519      None                     poiName
# 14  518      None                   poiOrigin
# 15  517      None                  provinceId
# 16  516      None                provinceName
# 17  515      None                 secondCatId
# 18  514      None               secondCatName
# ...
